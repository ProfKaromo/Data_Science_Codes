# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfKaromo/Data_Science_Codes/blob/main/Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
data = pandas.read_csv("https://modcom.co.ke/data/datasets/schoolcleaned.csv", 
                       parse_dates=['bday','enrolldate', 'expgradate'])
data.head(4)
# Out:
#    Unnamed: 0    ids       bday enrolldate expgradate      Rank       Major  \
# 0           0  43783 1995-03-22 2014-08-04 2019-05-13   Unknown      uknown
# 1          29  20230 1996-01-02 2014-08-04 2020-05-11  Freshmen  pre-pharma
# 2          30  21083 1995-12-22 2014-08-04 2020-05-11  Freshmen      uknown
# 3          31  21939 1995-12-12 2014-08-04 2020-05-11  Freshmen      uknown
#
#    Gender      Athlete  Height  ...   Math    Writing     State  LiveOnCampus  \
# 0    Male  Non-Athlete  217.05  ...  60.02  81.440000  In state     On Campus
# 1    Male      Athlete  240.33  ...  65.36  76.070000  In state     On Campus
# 2  Female  Non-Athlete  216.15  ...  68.53  71.420000  In state    Off Campus
# 3    Male      Athlete  198.27  ...  61.61  79.521683  In state    Off Campus
#
#    HowCommute  CommuteTime  SleepTime StudyTime Performance       Total
# 0       Other    27.149573        7.0       1.0      Failed  222.960000
# ...

# %%
#Matplotlib, Seaborn
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')
#count plot,

# %%
sns.countplot(data['Smoking'], palette='gnuplot2')
plt.title('Smoking Counts')
plt.xlabel('Smoking Students')
plt.ylabel('Smoking Students Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Smoking Students Count')

# %%
#Bar plot
import numpy
ax = sns.barplot(x='Gender', y='Math', data=data, estimator= numpy.mean, palette='Oranges', hue='Athlete')
for p in ax.patches:
  txt = str(p.get_height().round(1)) + ' '
  txt_x = p.get_x()
  txt_y = p.get_height()
  ax.text(txt_x,txt_y,txt)

# %%
#Dist plot
#sns.distplot(data['Math'])
sns.distplot(data['Math'], kde=False)
# for p in ax.patches:
#  txt = str(p.get_height().round(1)) + ' '
#  txt_x = p.get_x()
#  txt_y = p.get_height()
#  ax.text(txt_x,txt_y,txt)
plt.title('Distribution Graph')
plt.xlabel('Maths')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Counts')

# %%
#Swam plot
color = ['#B388FF','#64DD17','#E65100']
#sns.swarmplot(x='Gender', y='Math', data=data, palette =color, hue='Athlete')
#distribution by state
sns.swarmplot(x='Gender', y='Math', data=data, palette =color, hue='State')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 10.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.stripplot(x='Gender', y='Math', data=data, palette =color)

# %%
sns.violinplot(x='Gender', y='Math', data=data, palette =color)
